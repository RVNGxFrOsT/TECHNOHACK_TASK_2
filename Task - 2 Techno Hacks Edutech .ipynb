# %%
import pandas as pd

# %%
data = pd.read_csv("Iris.csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.SepalLengthCm.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: SepalLengthCm, Length: 150, dtype: bool

# %%
data.SepalLengthCm.duplicated().sum()
# Out:
# 115

# %%
data[data.SepalLengthCm.duplicated()]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 12    13            4.8           3.0            1.4           0.1
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 6       Iris-setosa
# 7       Iris-setosa
# 9       Iris-setosa
# 10      Iris-setosa
# 12      Iris-setosa
# ..              ...
# ...

# %%
data[data.SepalLengthCm.duplicated()].sum()
# Out:
# Id                                                            9484
# SepalLengthCm                                                666.1
# SepalWidthCm                                                 345.9
# PetalLengthCm                                                440.3
# PetalWidthCm                                                 143.5
# Species          Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# dtype: object

# %%
data.drop_duplicates(subset=['SepalLengthCm'])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 8      9            4.4           2.9            1.4           0.2
# 11    12            4.8           3.4            1.6           0.2
# 13    14            4.3           3.0            1.1           0.1
# 14    15            5.8           4.0            1.2           0.2
# 15    16            5.7           4.4            1.5           0.4
# 27    28            5.2           3.5            1.5           0.2
# 33    34            5.5           4.2            1.4           0.2
# ...

# %%
data.SepalWidthCm.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: SepalWidthCm, Length: 150, dtype: bool

# %%
data.SepalWidthCm.duplicated().sum()
# Out:
# 127

# %%
data[data.SepalWidthCm.duplicated()]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 7      8            5.0           3.4            1.5           0.2
# 9     10            4.9           3.1            1.5           0.1
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# 13    14            4.3           3.0            1.1           0.1
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 7       Iris-setosa
# 9       Iris-setosa
# 11      Iris-setosa
# 12      Iris-setosa
# 13      Iris-setosa
# ..              ...
# ...

# %%
data[data.SepalWidthCm.duplicated()].sum()
# Out:
# Id                                                           10647
# SepalLengthCm                                                756.0
# SepalWidthCm                                                 384.5
# PetalLengthCm                                                513.8
# PetalWidthCm                                                 167.7
# Species          Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# dtype: object

# %%
data.drop_duplicates(subset=['SepalWidthCm'])
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    1            5.1           3.5            1.4           0.2
# 1    2            4.9           3.0            1.4           0.2
# 2    3            4.7           3.2            1.3           0.2
# 3    4            4.6           3.1            1.5           0.2
# 4    5            5.0           3.6            1.4           0.2
# 5    6            5.4           3.9            1.7           0.4
# 6    7            4.6           3.4            1.4           0.3
# 8    9            4.4           2.9            1.4           0.2
# 10  11            5.4           3.7            1.5           0.2
# 14  15            5.8           4.0            1.2           0.2
# 15  16            5.7           4.4            1.5           0.4
# 18  19            5.7           3.8            1.7           0.3
# 23  24            5.1           3.3            1.7           0.5
# ...

# %%
data.drop_duplicates(subset=['SepalLengthCm', 'SepalWidthCm'])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 136  137            6.3           3.4            5.6           2.4
# 137  138            6.4           3.1            5.5           1.8
# 138  139            6.0           3.0            4.8           1.8
# 143  144            6.8           3.2            5.9           2.3
# 148  149            6.2           3.4            5.4           2.3
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.drop_duplicates(subset=['SepalLengthCm', 'SepalWidthCm'], keep = 'last')
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 1      2            4.9           3.0            1.4           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 6      7            4.6           3.4            1.4           0.3
# 8      9            4.4           2.9            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 1       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 6       Iris-setosa
# 8       Iris-setosa
# ..              ...
# ...

# %%
data.PetalLengthCm.duplicated()
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 145    False
# 146     True
# 147     True
# 148     True
# 149     True
# Name: PetalLengthCm, Length: 150, dtype: bool

# %%
data.PetalLengthCm.duplicated().sum()
# Out:
# 107

# %%
data[data.PetalLengthCm.duplicated()]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 1      2            4.9           3.0            1.4           0.2
# 4      5            5.0           3.6            1.4           0.2
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 144  145            6.7           3.3            5.7           2.5
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 1       Iris-setosa
# 4       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# 8       Iris-setosa
# ..              ...
# ...

# %%
data[data.PetalLengthCm.duplicated()].sum()
# Out:
# Id                                                            8209
# SepalLengthCm                                                614.6
# SepalWidthCm                                                 327.6
# PetalLengthCm                                                382.3
# PetalWidthCm                                                 120.3
# Species          Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# dtype: object

# %%
data.drop_duplicates(subset=['PetalLengthCm'])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 5      6            5.4           3.9            1.7           0.4
# 11    12            4.8           3.4            1.6           0.2
# 13    14            4.3           3.0            1.1           0.1
# 14    15            5.8           4.0            1.2           0.2
# 22    23            4.6           3.6            1.0           0.2
# 24    25            4.8           3.4            1.9           0.2
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 53    54            5.5           2.3            4.0           1.3
# ...

# %%
data.PetalWidthCm.duplicated()
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: PetalWidthCm, Length: 150, dtype: bool

# %%
data.PetalWidthCm.duplicated().sum()
# Out:
# 128

# %%
data[data.PetalWidthCm.duplicated()]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 7      8            5.0           3.4            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 7       Iris-setosa
# ..              ...
# ...

# %%
data[data.PetalWidthCm.duplicated()].sum()
# Out:
# Id                                                            9915
# SepalLengthCm                                                747.6
# SepalWidthCm                                                 390.3
# PetalLengthCm                                                476.6
# PetalWidthCm                                                 149.7
# Species          Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# dtype: object

# %%
data.drop_duplicates(subset=['PetalWidthCm'])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 9     10            4.9           3.1            1.5           0.1
# 23    24            5.1           3.3            1.7           0.5
# 43    44            5.0           3.5            1.6           0.6
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 53    54            5.5           2.3            4.0           1.3
# 56    57            6.3           3.3            4.7           1.6
# 57    58            4.9           2.4            3.3           1.0
# 69    70            5.6           2.5            3.9           1.1
# 70    71            5.9           3.2            4.8           1.8
# ...

# %%
data.drop_duplicates(subset=['PetalLengthCm', 'PetalWidthCm'])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 5       Iris-setosa
# 6       Iris-setosa
# ..              ...
# ...

# %%
data.drop_duplicates(subset=['PetalLengthCm', 'PetalWidthCm'], keep = 'last')
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 5      6            5.4           3.9            1.7           0.4
# 12    13            4.8           3.0            1.4           0.1
# 13    14            4.3           3.0            1.1           0.1
# 16    17            5.4           3.9            1.3           0.4
# 18    19            5.7           3.8            1.7           0.3
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 5       Iris-setosa
# 12      Iris-setosa
# 13      Iris-setosa
# 16      Iris-setosa
# 18      Iris-setosa
# ..              ...
# ...
